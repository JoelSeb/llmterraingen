# %% [markdown]
# Copyright (C) 2025 Joel Sebastian, github.com/JoelSeb
# <br>
# Licensed under the Apache License, Version 2.0 (the "License");
# <br>
# you may not use this file except in compliance with the License.
# <br>
# You may obtain a copy of the License at:
# <br>
# <br>
#     http://www.apache.org/licenses/LICENSE-2.0
# <br>
# <br>
# Unless required by applicable law or agreed to in writing, software
# <br>
# distributed under the License is distributed on an "AS IS" BASIS,
# <br>
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# <br>
# See the License for the specific language governing permissions and
# <br>
# limitations under the License.

# %%
import random

# %%
class BaseGenerator:
    def __init__(self):
        self.command = "/generate"

    def generate(self):
        raise NotImplementedError("Subclasses should implement this method")

    def getRandomParams(self):
        raise NotImplementedError("Subclasses should implement this method")

class Hill(BaseGenerator):
    def __init__(self, limits, seed):
        super().__init__()
        # Hill Limits: [xMin, xMax, zMin, zMax, maxHeight]
        self.limits = limits
        self.seed = seed

    def getRandomParams(self):
        random.seed(self.seed)
        bottomLeftX = random.randint(self.limits[0], self.limits[1])
        bottomLeftZ = random.randint(self.limits[2], self.limits[3])
        topRightX = random.randint(bottomLeftX, self.limits[1])
        topRightZ = random.randint(bottomLeftZ, self.limits[3])
        maxHeight = random.randint(1, self.limits[4])

        return f"{bottomLeftX} {bottomLeftZ} {topRightX} {topRightZ} {maxHeight} {self.seed}"

    def generate(self):
        params = self.getRandomParams()
        return f"{self.command} hill {params}"
    
class River(BaseGenerator):
    def __init__(self, limits, seed):
        super().__init__()
        # River Limits: [xMin, xMax, zMin, zMax, width]
        self.limits = limits
        self.seed = seed

    def getRandomParams(self):
        random.seed(self.seed)
        startX = random.randint(self.limits[0], self.limits[1])
        startZ = random.randint(self.limits[2], self.limits[3])
        endX = random.randint(self.limits[0], self.limits[1])
        endZ = random.randint(self.limits[2], self.limits[3])
        width = random.randint(1, self.limits[4])

        return f"{startX} {startZ} {endX} {endZ} {width} {self.seed}"

    def generate(self):
        params = self.getRandomParams()
        return f"{self.command} river {params}"
    
class Lake(BaseGenerator):
    def __init__(self, limits, seed):
        super().__init__()
        # Lake Limits: [xMin, xMax, zMin, zMax, radius]
        self.limits = limits
        self.seed = seed

    def getRandomParams(self):
        random.seed(self.seed)
        centreX = random.randint(self.limits[0], self.limits[1])
        centreZ = random.randint(self.limits[2], self.limits[3])
        type = random.choice(["circle", "square"])
        radius = random.randint(1, self.limits[4])
        
        if type == "circle":
            return f"{centreX} {centreZ} {type} {radius}"
        else:
            width = random.randint(1, self.limits[4])
            return f"{centreX} {centreZ} {type} {radius} {width}"

    def generate(self):
        params = self.getRandomParams()
        return f"{self.command} lake {params}"
    
class Village(BaseGenerator):
    def __init__(self, limits, seed):
        super().__init__()
        # Village Limits: [xMin, xMax, zMin, zMax]
        self.limits = limits
        self.seed = seed

    def getRandomParams(self):
        random.seed(self.seed)
        centreX = random.randint(self.limits[0], self.limits[1])
        centreZ = random.randint(self.limits[2], self.limits[3])

        return f"{centreX} {centreZ}"

    def generate(self):
        params = self.getRandomParams()
        return f"{self.command} village {params}"
    
class Forest(BaseGenerator):
    def __init__(self, limits, density, type, seed):
        super().__init__()
        # Forest Limits: [xMin, xMax, zMin, zMax, treeCount]
        self.limits = limits
        self.seed = seed
        self.density = density
        self.type = type

    def getRandomParams(self):
        random.seed(self.seed)
        centreX = random.randint(self.limits[0], self.limits[1])
        centreZ = random.randint(self.limits[2], self.limits[3])
        treeCount = random.randint(1, self.limits[4])

        return f"{centreX} {centreZ} {treeCount} {self.density} {self.type} {self.seed}"

    def generate(self):
        params = self.getRandomParams()
        return f"{self.command} forest {params}"
    
class Grass(BaseGenerator):
    def __init__(self, limits, density, seed):
        super().__init__()
        # Grass Limits: [xMin, xMax, zMin, zMax, radius]
        self.limits = limits
        self.seed = seed
        self.density = density

    def getRandomParams(self):
        random.seed(self.seed)
        centreX = random.randint(self.limits[0], self.limits[1])
        centreZ = random.randint(self.limits[2], self.limits[3])
        radius = random.randint(1, self.limits[4])

        return f"{centreX} {centreZ} {radius} {self.density}"

    def generate(self):
        params = self.getRandomParams()
        return f"{self.command} grass {params}"
    
class Flowers(BaseGenerator):
    def __init__(self, limits, density, seed):
        super().__init__()
        # Grass Limits: [xMin, xMax, zMin, zMax, radius]
        self.limits = limits
        self.seed = seed
        self.density = density

    def getRandomParams(self):
        random.seed(self.seed)
        centreX = random.randint(self.limits[0], self.limits[1])
        centreZ = random.randint(self.limits[2], self.limits[3])
        radius = random.randint(1, self.limits[4])

        return f"{centreX} {centreZ} {radius} {self.density} {self.seed}"

    def generate(self):
        params = self.getRandomParams()
        return f"{self.command} flowers {params}"

# %%
# Testing
hillGen = Hill([0, 255, 0, 255, 40], random.randint(0, 1000))
print(hillGen.generate()) 

riverGen = River([0, 255, 0, 255, 5], random.randint(0, 1000))
print(riverGen.generate())
# Out:
# /generate hill 31 44 215 92 29 585
# /generate river 102 2 89 195 4 636

# %%
# Coordinate boundaries for each tile
tiles = {
    "Central": [0, 0, 255, 255],
    "North": [0, 256, 255, 511],
    "East": [256, 0, 511, 255],
    "South": [0, -256, 255, -1],
    "West": [-256, 0, -1, 255],
    "NorthEast": [256, 256, 511, 511],
    "SouthEast": [256, -256, 511, -1],
    "SouthWest": [-256, -256, -1, -1],
    "NorthWest": [-256, 256, -1, 511]
}

def genWorld(genLimits):
    random.seed(None)
    globalSeed = random.randint(0, 1000)
    random.seed(globalSeed)
    print(f"Global Seed: {globalSeed}\n")
    for tileName, coords in tiles.items():
        print(f"Tile: {tileName}")
        for i in range(random.randint(0, genLimits["hillCount"])):
            hillGen = Hill([coords[0], coords[2], coords[1], coords[3], genLimits["hillHeight"]], random.randint(0, 1000))
            print(hillGen.generate())

        for i in range(random.randint(0, genLimits["riverCount"])):
            riverGen = River([coords[0], coords[2], coords[1], coords[3], genLimits["riverWidth"]], random.randint(0, 1000))
            print(riverGen.generate())

        for i in range(random.randint(0, genLimits["lakeCount"])):
            lakeGen = Lake([coords[0], coords[2], coords[1], coords[3], genLimits["lakeRadius"]], random.randint(0, 1000))
            print(lakeGen.generate())

        for i in range(random.randint(0, genLimits["villageCount"])):
            villageGen = Village([coords[0], coords[2], coords[1], coords[3]], random.randint(0, 1000))
            print(villageGen.generate())

        for i in range(random.randint(0, genLimits["forestCount"])):
            forestGen = Forest([coords[0], coords[2], coords[1], coords[3], genLimits["treeCount"]],
                                random.choices(
                                    ["low", "med", "high"], 
                                    weights=[
                                        genLimits["densityLowProbability"], 
                                        genLimits["densityMedProbability"], 
                                        genLimits["densityHighProbability"]
                                    ]
                                )[0], random.choice(["oak", "birch", "any"]), random.randint(0, 1000))
            print(forestGen.generate())

        for i in range(random.randint(0, genLimits["grassCount"])):
            grassGen = Grass([coords[0], coords[2], coords[1], coords[3], genLimits["grassRadius"]],
                                random.choices(
                                    ["low", "med", "high"], 
                                    weights=[
                                        genLimits["densityLowProbability"], 
                                        genLimits["densityMedProbability"], 
                                        genLimits["densityHighProbability"]
                                    ]
                                )[0], random.randint(0, 1000))
            print(grassGen.generate())

        for i in range(random.randint(0, genLimits["flowersCount"])):
            flowersGen = Flowers([coords[0], coords[2], coords[1], coords[3], genLimits["flowersRadius"]],
                                random.choices(
                                    ["low", "med", "high"], 
                                    weights=[
                                        genLimits["densityLowProbability"], 
                                        genLimits["densityMedProbability"], 
                                        genLimits["densityHighProbability"]
                                    ]
                                )[0], random.randint(0, 1000))
            print(flowersGen.generate())
        print()

# %%
first_limits = {
    "hillCount": 10, "hillHeight": 40,
    "riverCount": 10, "riverWidth": 20,
    "lakeCount": 10, "lakeRadius": 60,
    "villageCount": 1,
    "forestCount": 10, "forestRadius": 50, "treeCount": 30,
    "grassCount": 30, "grassRadius": 50,
    "flowersCount": 10, "flowersRadius": 50,
    "densityLowProbability": 0.8, "densityMedProbability": 0.15, "densityHighProbability": 0.05
}

genWorld(first_limits)
# Out:
# Global Seed: 495
#
# Tile: Central
# /generate hill 117 44 201 152 21 167
# /generate hill 20 135 222 172 17 990
# /generate hill 132 227 146 252 37 837
# /generate hill 20 46 131 198 32 259
# /generate hill 180 98 232 132 25 670
# /generate hill 245 76 253 183 7 409
# /generate hill 64 10 227 175 18 443
# /generate hill 96 255 136 255 37 343
# /generate hill 93 63 164 140 28 94
# /generate hill 211 203 226 242 15 869
# /generate river 199 203 93 156 4 847
# /generate river 238 229 153 143 6 997
# /generate river 244 26 19 102 4 368
# /generate river 190 161 20 95 9 487
# /generate river 5 84 52 179 1 769
# /generate river 106 209 233 235 15 840
# /generate river 122 106 200 159 7 358
# /generate forest 110 233 17 low any 53
# /generate grass 217 66 2 low
# /generate grass 243 63 41 low
# /generate grass 103 240 11 low
# /generate grass 10 38 43 high
# /generate grass 5 84 40 low
# /generate grass 116 191 49 low
# /generate grass 102 54 21 low
# /generate grass 14 107 50 med
# /generate grass 63 226 7 low
# /generate grass 72 214 26 low
# /generate grass 135 176 41 low
# /generate grass 218 159 12 low
# /generate grass 144 198 37 med
# /generate grass 65 252 2 low
# /generate grass 132 148 44 low
# /generate grass 251 155 49 med
# /generate grass 189 253 47 low
# /generate grass 45 232 1 low
# /generate grass 141 200 9 low
# /generate grass 79 47 26 low
# /generate grass 7 141 26 med
# /generate grass 39 204 3 low
# /generate flowers 17 201 12 low 908
# /generate flowers 91 20 45 low 319
# /generate flowers 187 62 15 low 626
# /generate flowers 37 92 27 low 137
# /generate flowers 7 67 11 low 197
# /generate flowers 191 153 6 low 192
# /generate flowers 16 170 43 low 966
# /generate flowers 36 25 26 low 330
# /generate flowers 152 76 4 low 341
#
# Tile: North
# /generate river 35 307 228 355 18 266
# /generate river 252 342 123 331 6 391
# /generate river 183 459 214 419 2 941
# /generate river 228 485 25 267 5 861
# /generate river 201 320 41 501 19 797
# /generate river 91 477 32 473 1 489
# /generate river 110 489 247 440 15 53
# /generate river 112 443 80 270 14 745
# /generate lake 22 350 square 54 7
# /generate lake 70 324 circle 6
# /generate lake 121 263 circle 16
# /generate lake 11 404 square 45 30
# /generate lake 36 306 square 25 9
# /generate lake 99 451 square 45 20
# /generate lake 77 464 circle 19
# /generate lake 77 389 circle 56
# /generate village 140 316
# /generate forest 205 488 16 low any 795
# /generate forest 217 311 29 low birch 792
# /generate forest 231 300 20 high birch 910
# /generate forest 142 258 6 low birch 124
# /generate forest 83 426 24 med oak 426
# /generate forest 4 296 10 low oak 206
# /generate forest 104 295 28 high oak 862
# /generate forest 93 403 25 low any 995
# /generate forest 155 310 19 med oak 988
# /generate grass 83 474 31 low
# /generate grass 7 323 11 med
# /generate grass 191 409 6 low
# /generate flowers 185 291 34 low 434
# /generate flowers 190 437 17 low 518
# /generate flowers 78 365 12 low 526
# /generate flowers 191 417 11 low 393
# /generate flowers 198 344 3 med 960
# /generate flowers 156 500 2 low 864
# /generate flowers 197 496 27 low 202
#
# Tile: East
# /generate hill 279 104 467 111 10 200
# /generate hill 443 119 511 128 1 632
# /generate hill 288 152 288 169 13 309
# /generate river 398 100 284 130 19 208
# /generate river 507 101 392 75 2 637
# /generate river 360 241 298 109 17 463
# /generate lake 329 40 circle 40
# /generate village 398 2
# /generate forest 339 170 24 med oak 426
# /generate forest 260 40 10 low oak 206
# /generate grass 473 139 48 low
# /generate grass 305 252 41 low
# /generate grass 474 159 12 low
# /generate grass 400 198 37 med
# /generate grass 321 252 2 low
# /generate grass 388 148 44 low
# /generate grass 507 155 49 med
# /generate grass 445 253 47 low
# /generate grass 301 232 1 low
# /generate grass 397 200 9 low
# /generate grass 335 47 26 low
# /generate grass 263 141 26 med
# /generate grass 295 204 3 low
# /generate grass 310 47 47 low
# /generate grass 390 116 45 low
# /generate grass 421 4 17 low
# /generate grass 455 109 37 high
# /generate grass 409 95 7 high
# /generate grass 374 193 5 low
# /generate grass 313 239 42 low
# /generate grass 425 111 24 low
# /generate grass 502 73 32 low
# /generate grass 294 197 48 low
# /generate flowers 284 46 6 low 2
# /generate flowers 421 249 43 low 173
#
# Tile: South
# /generate hill 67 -152 247 -28 39 608
# /generate hill 90 -126 155 -88 7 951
# /generate hill 130 -4 215 -1 18 421
# /generate hill 127 -42 227 -31 1 332
# /generate hill 71 -141 207 -31 17 229
# /generate hill 28 -102 193 -94 35 845
# /generate hill 116 -65 140 -55 16 900
# /generate hill 129 -221 138 -212 32 736
# /generate river 45 -24 6 -145 11 390
# /generate lake 158 -27 circle 41
# /generate lake 68 -215 square 37 15
# /generate lake 23 -218 square 21 50
# /generate lake 58 -166 square 20 38
# /generate lake 231 -63 circle 50
# /generate lake 64 -246 square 25 17
# /generate lake 58 -67 square 12 15
# /generate lake 110 -228 circle 32
# /generate lake 74 -32 square 39 11
# /generate lake 30 -58 square 5 47
# /generate village 73 -216
# /generate forest 142 -254 6 low birch 124
# /generate forest 83 -86 24 med oak 426
# /generate forest 4 -216 10 low oak 206
# /generate forest 104 -217 28 high oak 862
# /generate forest 93 -109 25 low any 995
# /generate forest 155 -202 19 med oak 988
# /generate forest 83 -38 16 low oak 313
# /generate forest 45 -79 6 med oak 858
# /generate forest 104 -170 8 low any 161
# /generate forest 32 -153 30 med any 604
# /generate grass 119 -70 16 low
# /generate grass 231 -76 15 low
# /generate grass 30 -29 21 low
# /generate grass 235 -118 40 low
# /generate grass 206 -182 15 med
# /generate grass 53 -151 23 low
# /generate grass 105 -251 14 low
# /generate grass 227 -136 4 med
# /generate grass 132 -252 19 low
# /generate grass 187 -29 40 low
# /generate grass 101 -2 5 low
# /generate grass 22 -67 4 low
# /generate flowers 237 -65 18 low 9
# /generate flowers 253 -62 32 low 887
# /generate flowers 222 -10 47 med 205
# /generate flowers 60 -155 2 low 866
# /generate flowers 234 -57 46 low 911
#
# Tile: West
# /generate hill -65 141 -3 178 8 135
# /generate hill -152 241 -11 255 6 463
# /generate hill -129 134 -89 216 36 855
# /generate hill -226 233 -163 253 12 126
# /generate hill -95 135 -85 135 3 483
# /generate hill -197 242 -154 252 12 525
# /generate river -148 161 -4 99 13 111
# /generate river -173 170 -77 39 7 426
# /generate river -254 118 -59 128 14 953
# /generate river -58 205 -176 34 2 250
# /generate river -147 203 -126 141 20 572
# /generate river -10 223 -145 246 15 857
# /generate river -87 96 -229 149 18 976
# /generate river -121 176 -31 76 20 600
# /generate river -198 25 -23 96 2 952
# /generate lake -199 12 square 16 15
# /generate lake -7 84 square 19 23
# /generate village -49 155
# /generate forest -93 93 7 low birch 348
# /generate forest -214 88 22 low birch 91
# /generate forest -122 116 30 low birch 971
# /generate forest -91 4 9 low oak 71
# /generate grass -53 43 38 med
# /generate grass -126 252 43 low
# /generate grass -129 214 45 low
# /generate grass -203 29 22 low
# /generate flowers -61 90 50 med 770
# /generate flowers -79 177 35 low 905
# /generate flowers -108 42 2 low 23
# /generate flowers -155 254 5 low 433
# /generate flowers -234 189 4 low 633
#
# Tile: NorthEast
# /generate hill 388 404 475 491 12 13
# /generate hill 308 478 477 504 23 667
# /generate hill 492 266 504 270 13 317
# /generate hill 451 464 506 473 15 253
# /generate hill 499 319 509 475 26 64
# /generate river 458 366 366 391 16 942
# /generate river 259 332 498 348 18 619
# /generate river 461 397 376 380 2 891
# /generate river 411 422 390 473 18 454
# /generate river 458 277 286 409 18 212
# /generate river 508 437 502 421 20 133
# /generate river 438 399 506 279 17 827
# /generate river 343 333 437 354 13 503
# /generate lake 304 271 square 2 35
# /generate lake 489 484 circle 28
# /generate lake 313 325 square 4 35
# /generate lake 425 367 square 2 58
# /generate village 296 276
# /generate forest 378 362 13 low oak 358
# /generate forest 441 496 16 low oak 16
# /generate forest 349 431 18 low oak 457
# /generate forest 496 325 14 low any 664
# /generate forest 403 285 4 low oak 412
# /generate forest 349 456 21 high oak 305
# /generate grass 366 511 27 low
# /generate grass 390 438 27 low
# /generate grass 309 402 35 low
# /generate grass 456 331 24 low
# /generate grass 334 365 12 high
# /generate grass 447 417 11 low
# /generate grass 454 344 3 med
# /generate grass 412 500 2 low
# /generate grass 453 496 27 low
# /generate grass 279 360 48 med
# /generate grass 324 327 40 low
# /generate grass 384 500 23 low
# /generate grass 492 344 20 med
# /generate grass 394 407 4 low
# /generate grass 451 426 15 low
# /generate grass 500 335 39 high
# /generate grass 310 310 41 low
# /generate grass 393 283 16 low
# /generate grass 278 306 2 low
# /generate grass 385 480 22 low
# /generate grass 369 337 2 low
# /generate flowers 402 469 35 high 155
# /generate flowers 361 409 31 low 829
# /generate flowers 344 478 35 med 605
# /generate flowers 509 349 36 low 61
# /generate flowers 412 464 35 low 928
# /generate flowers 293 348 27 low 137
# /generate flowers 263 323 11 low 197
# /generate flowers 447 409 6 low 192
# /generate flowers 272 426 43 low 966
# /generate flowers 292 281 26 low 330
#
# Tile: SouthEast
# /generate hill 441 -16 502 -7 27 16
# /generate hill 399 -193 428 -173 5 232
# /generate hill 389 -88 441 -10 15 875
# /generate hill 498 -24 511 -16 21 617
# /generate hill 388 -29 402 -4 37 837
# /generate hill 276 -210 387 -58 32 259
# /generate hill 436 -158 488 -124 25 670
# /generate hill 501 -180 509 -73 7 409
# /generate river 271 -38 374 -143 8 895
# /generate river 365 -129 461 -180 11 781
# /generate river 309 -69 402 -241 2 492
# /generate river 274 -160 402 -256 1 655
# /generate river 273 -55 350 -233 10 908
# /generate river 282 -102 424 -239 8 977
# /generate lake 443 -137 circle 56
# /generate lake 369 -35 circle 56
# /generate lake 317 -48 circle 25
# /generate lake 463 -101 square 48 55
# /generate lake 365 -155 circle 43
# /generate lake 438 -234 square 27 4
# /generate lake 349 -109 circle 28
# /generate lake 269 -250 square 57 52
# /generate lake 487 -18 square 33 55
# /generate lake 354 -238 circle 30
# /generate village 402 -42
# /generate forest 457 -169 22 low oak 159
# /generate forest 484 -27 30 low any 861
# /generate forest 395 -233 29 low oak 129
# /generate forest 335 -209 13 med any 978
# /generate forest 474 -97 6 med any 980
# /generate forest 500 -16 4 med birch 293
# /generate grass 269 -70 18 low
# /generate grass 312 -127 21 low
# /generate grass 283 -194 19 low
# /generate grass 487 -212 40 low
# /generate grass 347 -236 45 low
# /generate grass 443 -194 15 low
# /generate grass 293 -164 27 low
# /generate flowers 445 -3 47 high 236
# /generate flowers 301 -24 1 low 390
# /generate flowers 397 -56 9 low 321
# /generate flowers 335 -209 26 low 978
# /generate flowers 263 -115 26 med 546
#
# Tile: SouthWest
# /generate hill -168 -97 -87 -36 4 915
# /generate hill -74 -113 -12 -35 3 827
# /generate hill -118 -105 -112 -4 26 538
# /generate hill -61 -86 -47 -65 25 41
# /generate hill -63 -199 -35 -167 6 591
# /generate hill -203 -227 -118 -141 13 181
# /generate river -64 -178 -167 -18 13 771
# /generate river -67 -19 -57 -154 10 76
# /generate river -186 -32 -104 -9 16 54
# /generate river -76 -44 -144 -132 16 389
# /generate lake -37 -225 square 32 49
# /generate lake -252 -216 square 48 15
# /generate lake -152 -217 circle 9
# /generate lake -191 -212 circle 13
# /generate lake -188 -150 square 33 55
# /generate lake -35 -217 circle 55
# /generate forest -70 -170 21 med any 502
# /generate forest -197 -221 11 low any 714
# /generate forest -174 -202 29 low birch 816
# /generate forest -95 -189 18 low oak 48
# /generate forest -240 -53 20 low birch 812
# /generate forest -138 -100 8 med birch 360
# /generate forest -229 -241 1 med oak 987
# /generate forest -67 -19 13 low oak 76
# /generate grass -186 -32 36 med
# /generate grass -22 -57 46 low
# /generate grass -65 -115 32 med
# /generate grass -179 -163 20 low
# /generate grass -46 -249 39 med
# /generate grass -128 -12 23 low
# /generate flowers -150 -251 34 low 15
# /generate flowers -152 -170 15 low 161
#
# Tile: NorthWest
# /generate hill -224 359 -126 452 37 604
# /generate hill -134 362 -34 441 13 358
# /generate hill -71 496 -10 505 27 16
# /generate hill -113 319 -84 339 5 232
# /generate hill -123 424 -71 502 15 875
# /generate hill -14 488 -1 496 21 617
# /generate hill -124 483 -110 508 37 837
# /generate hill -236 302 -125 454 32 259
# /generate hill -76 354 -24 388 25 670
# /generate hill -11 332 -3 439 7 409
# /generate river -241 474 -138 369 8 895
# /generate river -147 383 -51 332 11 781
# /generate river -203 443 -110 271 2 492
# /generate river -238 352 -110 256 1 655
# /generate river -239 457 -162 279 10 908
# /generate river -230 410 -88 273 8 977
# /generate lake -69 375 circle 56
# /generate lake -143 477 circle 56
# /generate lake -195 464 circle 25
# /generate lake -49 411 square 48 55
# /generate lake -147 357 circle 43
# /generate lake -74 278 square 27 4
# /generate lake -163 403 circle 28
# /generate lake -243 262 square 57 52
# /generate lake -25 494 square 33 55
# /generate lake -158 274 circle 30
# /generate village -110 470
# /generate forest -55 343 22 low oak 159
# /generate forest -28 485 30 low any 861
# /generate forest -117 279 29 low oak 129
# /generate forest -177 303 13 med any 978
# /generate forest -38 415 6 med any 980
# /generate forest -12 496 4 med birch 293
# /generate grass -243 442 18 low
# /generate grass -200 385 21 low
# /generate grass -229 318 19 low
# /generate grass -25 300 40 low
# /generate grass -165 276 45 low
# /generate grass -69 318 15 low
# /generate grass -219 348 27 low
# /generate flowers -67 509 47 high 236
# /generate flowers -211 488 1 low 390
# /generate flowers -115 456 9 low 321
# /generate flowers -177 303 26 low 978
# /generate flowers -249 397 26 med 546

# %%
second_limits = {
    "hillCount": 20, "hillHeight": 40,
    "riverCount": 30, "riverWidth": 30,
    "lakeCount": 20, "lakeRadius": 100,
    "villageCount": 1,
    "forestCount": 10, "forestRadius": 50, "treeCount": 30,
    "grassCount": 30, "grassRadius": 50,
    "flowersCount": 10, "flowersRadius": 50,
    "densityLowProbability": 0.8, "densityMedProbability": 0.15, "densityHighProbability": 0.05
}

genWorld(second_limits)
# Out:
# Global Seed: 545
#
# Tile: Central
# /generate hill 198 174 231 199 6 643
# /generate hill 37 129 132 193 3 296
# /generate hill 177 35 225 145 22 647
# /generate hill 189 161 239 187 7 96
# /generate hill 132 227 146 252 37 837
# /generate hill 20 46 131 198 32 259
# /generate river 83 37 213 203 17 764
# /generate river 195 208 74 116 3 253
# /generate river 253 194 249 100 7 887
# /generate river 64 10 198 198 9 813
# /generate river 58 189 194 94 8 168
# /generate river 110 28 118 255 3 545
# /generate river 232 235 104 250 7 392
# /generate river 53 242 158 21 26 326
# /generate river 212 27 155 87 18 477
# /generate river 64 240 98 151 2 594
# /generate river 180 32 220 232 19 47
# /generate river 177 164 139 163 24 351
# /generate river 208 243 96 19 13 302
# /generate river 53 146 207 187 20 407
# /generate river 17 245 125 215 9 765
# /generate river 53 29 171 173 27 181
# /generate river 14 107 216 161 26 196
# /generate river 139 201 215 188 12 80
# /generate river 110 28 118 255 3 545
# /generate river 232 235 104 250 7 392
# /generate lake 222 246 circle 69
# /generate lake 60 101 circle 19
# /generate lake 122 106 square 96 40
# /generate lake 234 199 square 17 23
# /generate lake 66 39 circle 44
# /generate lake 253 194 square 26 26
# /generate lake 64 10 square 50 34
# /generate lake 58 189 square 24 29
# /generate lake 110 28 circle 64
# /generate lake 74 224 square 77 21
# /generate forest 112 52 2 low birch 158
# /generate forest 117 228 15 low birch 777
# /generate forest 190 35 7 high any 276
# /generate grass 180 15 39 low
# /generate grass 165 145 5 low
# /generate grass 44 241 18 low
# /generate grass 63 190 36 low
# /generate grass 55 46 48 low
# /generate grass 144 76 19 med
# /generate grass 6 30 26 low
# /generate grass 48 15 18 low
# /generate grass 233 228 49 low
# /generate grass 91 205 45 low
# /generate grass 249 213 48 low
# /generate grass 35 249 47 low
# /generate grass 36 50 17 low
# /generate grass 99 195 29 low
# /generate grass 95 75 26 med
# /generate grass 110 175 34 low
# /generate grass 40 251 31 low
# /generate grass 65 163 23 low
# /generate grass 250 158 28 med
# /generate grass 128 244 23 low
# /generate grass 236 88 20 med
# /generate grass 138 151 4 low
# /generate grass 195 170 15 low
# /generate grass 244 79 39 high
# /generate grass 54 54 41 low
# /generate grass 137 27 16 low
# /generate grass 22 50 2 low
# /generate grass 129 224 22 low
# /generate grass 113 81 2 low
# /generate grass 109 101 6 low
# /generate flowers 110 100 30 low 783
# /generate flowers 91 254 9 low 754
# /generate flowers 53 29 22 low 181
# /generate flowers 127 134 11 med 855
# /generate flowers 159 51 20 low 574
# /generate flowers 218 159 12 low 980
# /generate flowers 144 198 37 med 285
# /generate flowers 65 252 2 low 95
# /generate flowers 132 148 44 low 13
# /generate flowers 251 155 49 med 821
#
# Tile: North
# /generate hill 152 366 172 371 23 963
# /generate hill 180 354 232 388 25 670
# /generate hill 245 332 253 439 7 409
# /generate hill 64 266 227 431 18 443
# /generate hill 96 511 136 511 37 343
# /generate hill 93 319 164 396 28 94
# /generate hill 211 459 226 498 15 869
# /generate hill 129 501 180 502 2 467
# /generate hill 249 288 255 494 25 432
# /generate hill 71 331 111 454 22 485
# /generate hill 87 274 224 314 20 363
# /generate river 102 310 164 354 8 85
# /generate river 79 356 232 285 22 472
# /generate lake 123 306 square 86 32
# /generate lake 195 262 circle 55
# /generate lake 205 488 square 22 38
# /generate lake 74 451 circle 95
# /generate lake 209 360 square 37 48
# /generate forest 104 450 2 low oak 468
# /generate forest 149 511 16 low oak 712
# /generate forest 46 277 27 low birch 203
# /generate forest 38 433 20 low oak 29
# /generate forest 203 353 11 med birch 88
# /generate forest 54 382 9 med any 14
# /generate forest 57 421 14 low birch 751
# /generate grass 163 349 14 low
# /generate grass 68 491 23 low
# /generate grass 141 320 8 low
# /generate grass 104 450 4 low
# /generate grass 74 462 49 low
# /generate grass 242 498 36 low
# /generate grass 129 422 13 low
# /generate grass 34 505 12 low
# /generate grass 177 420 47 low
# /generate grass 145 276 2 low
# /generate grass 216 336 26 low
# /generate grass 148 339 43 low
# /generate grass 157 339 34 low
# /generate grass 172 490 5 low
# /generate grass 180 354 27 low
# /generate grass 245 332 36 low
# /generate grass 183 371 23 med
# /generate flowers 112 284 9 low 981
# /generate flowers 16 426 43 low 966
# /generate flowers 36 281 26 low 330
# /generate flowers 152 332 4 low 341
# /generate flowers 159 307 20 low 574
# /generate flowers 218 415 12 low 980
# /generate flowers 144 454 37 med 285
#
# Tile: East
# /generate hill 391 152 476 184 27 469
# /generate hill 345 212 424 217 35 661
# /generate hill 371 113 436 194 8 761
# /generate hill 438 177 503 230 1 595
# /generate hill 327 115 463 225 17 229
# /generate hill 284 154 449 162 35 845
# /generate hill 372 191 396 201 16 900
# /generate hill 385 35 394 44 32 736
# /generate hill 330 235 446 240 26 100
# /generate hill 489 228 509 233 28 749
# /generate hill 313 69 472 147 4 323
# /generate hill 498 96 508 242 30 556
# /generate hill 428 116 477 212 8 832
# /generate hill 402 213 471 247 27 155
# /generate hill 361 153 481 177 38 829
# /generate hill 456 76 483 246 30 956
# /generate hill 476 150 483 224 10 901
# /generate hill 445 172 447 188 39 395
# /generate river 300 111 459 90 20 121
# /generate river 496 163 504 38 18 818
# /generate river 300 241 397 137 19 930
# /generate river 389 115 289 200 18 573
# /generate river 368 28 326 180 29 981
# /generate river 272 170 505 165 15 966
# /generate river 436 212 368 124 16 389
# /generate river 473 66 267 249 3 735
# /generate river 283 246 307 244 15 198
# /generate river 326 224 408 247 29 54
# /generate river 368 28 326 180 29 981
# /generate river 272 170 505 165 15 966
# /generate river 436 212 368 124 16 389
# /generate river 473 66 267 249 3 735
# /generate river 283 246 307 244 15 198
# /generate river 326 224 408 247 29 54
# /generate river 368 28 326 180 29 981
# /generate river 272 170 505 165 15 966
# /generate river 436 212 368 124 16 389
# /generate lake 475 31 square 64 98
# /generate lake 260 40 square 95 29
# /generate lake 360 39 circle 18
# /generate lake 321 44 circle 25
# /generate lake 324 106 square 65 58
# /generate lake 261 242 square 99 70
# /generate lake 258 118 square 90 33
# /generate lake 455 145 square 62 88
# /generate lake 403 29 circle 26
# /generate lake 378 92 circle 27
# /generate lake 501 76 square 82 13
# /generate lake 320 10 square 43 37
# /generate forest 361 203 21 low birch 909
# /generate forest 493 191 9 med oak 9
# /generate forest 297 248 25 low any 6
# /generate forest 292 50 9 low oak 149
# /generate grass 261 242 42 low
# /generate grass 445 24 46 low
# /generate grass 375 127 30 low
# /generate grass 366 13 21 low
# /generate grass 290 166 27 low
# /generate grass 395 95 6 low
# /generate grass 309 105 23 low
# /generate grass 361 5 14 low
# /generate grass 483 120 4 med
# /generate grass 388 4 19 low
# /generate grass 443 227 40 low
# /generate grass 357 254 5 low
#
# Tile: South
# /generate hill 22 -67 236 -61 23 633
# /generate hill 132 -108 219 -21 12 13
# /generate hill 52 -34 221 -8 23 667
# /generate hill 236 -246 248 -242 13 317
# /generate hill 195 -48 250 -39 15 253
# /generate hill 243 -193 253 -37 26 64
# /generate hill 103 -16 144 -1 12 549
# /generate hill 144 -16 184 -1 5 295
# /generate hill 68 -215 224 -109 37 937
# /generate hill 189 -3 234 -3 25 236
# /generate hill 43 -2 55 -2 36 725
# /generate hill 197 -121 231 -116 34 558
# /generate hill 149 -1 211 -1 28 712
# /generate hill 46 -235 171 -82 14 203
# /generate hill 38 -79 191 -2 19 29
# /generate river 39 -137 197 -246 5 522
# /generate river 36 -164 165 -100 27 748
# /generate lake 39 -52 circle 76
# /generate lake 135 -80 square 20 78
# /generate lake 58 -231 square 25 5
# /generate lake 130 -167 circle 68
# /generate lake 25 -62 circle 77
# /generate lake 74 -61 circle 95
# /generate lake 209 -152 square 37 48
# /generate lake 166 -235 square 57 31
# /generate lake 150 -106 circle 49
# /generate lake 158 -109 circle 40
# /generate lake 231 -63 circle 99
# /generate lake 64 -246 square 50 34
# /generate grass 188 -34 4 low
# /generate grass 106 -214 48 low
# /generate grass 121 -249 14 med
# /generate grass 129 -253 33 low
# /generate grass 197 -75 6 low
# /generate grass 242 -91 25 low
# /generate grass 236 -164 50 low
# /generate grass 169 -177 46 low
# /generate grass 1 -229 43 low
# /generate grass 56 -45 18 low
# /generate grass 203 -213 38 low
# /generate grass 130 -4 43 low
# /generate grass 127 -42 45 low
# /generate grass 53 -227 22 low
# /generate grass 127 -122 11 med
# /generate grass 159 -205 20 low
# /generate grass 218 -97 12 low
# /generate grass 144 -58 37 med
# /generate grass 65 -4 2 low
# /generate grass 132 -108 44 low
# /generate grass 251 -101 49 med
# /generate grass 189 -3 47 low
# /generate grass 45 -24 1 low
# /generate grass 141 -56 9 low
# /generate grass 79 -209 26 low
# /generate grass 7 -115 26 med
# /generate grass 39 -52 3 low
# /generate grass 54 -209 47 low
# /generate flowers 119 -154 38 high 682
# /generate flowers 34 -223 44 low 677
# /generate flowers 37 -17 33 low 592
# /generate flowers 209 -152 23 low 151
#
# Tile: West
# /generate hill -73 137 -73 152 20 940
# /generate hill -188 41 -32 147 37 937
# /generate hill -67 253 -22 253 25 236
# /generate hill -213 254 -201 254 36 725
# /generate hill -59 135 -25 140 34 558
# /generate hill -107 255 -45 255 28 712
# /generate hill -210 21 -85 174 14 203
# /generate hill -218 177 -65 254 19 29
# /generate hill -53 97 -32 144 1 88
# /generate river -67 24 -116 110 6 786
# /generate river -192 240 -158 151 2 594
# /generate river -76 32 -36 232 19 47
# /generate river -79 164 -117 163 24 351
# /generate river -48 243 -160 19 13 302
# /generate river -203 146 -49 187 20 407
# /generate river -239 245 -131 215 9 765
# /generate river -203 29 -85 173 27 181
# /generate river -242 107 -40 161 26 196
# /generate river -117 201 -41 188 12 80
# /generate river -146 28 -138 255 3 545
# /generate river -24 235 -152 250 7 392
# /generate river -203 242 -98 21 26 326
# /generate river -44 27 -101 87 18 477
# /generate river -192 240 -158 151 2 594
# /generate river -76 32 -36 232 19 47
# /generate lake -38 173 square 93 33
# /generate lake -219 92 square 42 25
# /generate lake -67 253 square 11 49
# /generate lake -213 254 circle 1
# /generate lake -184 163 square 11 95
# /generate lake -95 187 square 85 11
# /generate lake -49 70 square 81 2
# /generate lake -46 141 square 6 53
# /generate lake -79 19 circle 10
# /generate lake -3 180 circle 12
# /generate village -47 104
# /generate forest -90 21 21 high birch 587
# /generate forest -236 65 16 low birch 451
# /generate forest -155 187 26 low oak 992
# /generate forest -77 180 7 med any 333
# /generate forest -117 95 3 high oak 289
# /generate grass -60 93 14 low
# /generate grass -229 246 7 high
# /generate grass -165 221 33 low
# /generate grass -10 223 43 med
# /generate grass -121 152 43 low
# /generate grass -167 212 20 low
# /generate grass -191 163 23 med
# /generate grass -6 158 28 med
# /generate grass -128 244 23 low
# /generate grass -20 88 20 med
# /generate grass -118 151 4 low
# /generate grass -61 170 15 low
# /generate grass -12 79 39 high
# /generate grass -202 54 41 low
# /generate flowers -235 177 12 low 470
# /generate flowers -94 208 42 low 920
# /generate flowers -182 206 49 low 191
# /generate flowers -14 242 36 low 490
# /generate flowers -127 166 13 low 77
# /generate flowers -222 249 12 low 842
# /generate flowers -79 164 47 low 351
#
# Tile: NorthEast
# /generate hill 309 498 388 498 30 326
# /generate hill 429 382 464 431 14 415
# /generate hill 345 264 364 419 13 933
# /generate hill 271 499 316 508 30 141
# /generate hill 324 288 389 318 32 1
# /generate hill 345 462 473 474 15 779
# /generate hill 500 496 501 503 33 293
# /generate hill 472 357 501 489 10 534
# /generate river 257 303 510 260 29 364
# /generate river 501 397 402 356 3 27
# /generate river 292 415 478 382 26 66
# /generate river 486 494 478 455 26 456
# /generate river 487 300 395 415 4 910
# /generate river 310 466 334 316 30 932
# /generate river 441 496 502 401 14 16
# /generate river 399 319 375 297 3 232
# /generate lake 362 465 square 71 59
# /generate lake 290 408 square 42 46
# /generate lake 454 461 circle 72
# /generate lake 463 326 square 81 2
# /generate lake 466 397 square 6 53
# /generate lake 433 275 circle 10
# /generate lake 509 436 circle 12
# /generate lake 343 274 circle 39
# /generate forest 386 508 22 low any 421
# /generate grass 446 270 30 low
# /generate grass 395 340 36 low
# /generate grass 465 452 38 med
# /generate grass 442 380 33 low
# /generate grass 276 391 19 low
# /generate grass 388 483 8 low
# /generate grass 276 302 28 med
# /generate grass 332 387 20 low
# /generate grass 389 371 31 low
# /generate grass 296 507 31 low
# /generate grass 321 419 23 low
# /generate grass 506 414 28 med
# /generate grass 384 500 23 low
# /generate grass 492 344 20 med
# /generate grass 394 407 4 low
# /generate flowers 276 302 28 low 259
# /generate flowers 332 387 20 low 505
# /generate flowers 389 371 31 low 718
# /generate flowers 296 507 31 low 999
# /generate flowers 321 419 23 low 817
# /generate flowers 506 414 28 med 256
#
# Tile: SouthEast
# /generate hill 452 -232 502 -96 2 384
# /generate hill 474 -97 485 -70 18 980
# /generate hill 500 -16 501 -9 33 293
# /generate hill 472 -155 501 -23 10 534
# /generate hill 506 -98 509 -52 25 256
# /generate hill 384 -12 474 -10 13 826
# /generate hill 443 -137 511 -128 1 632
# /generate hill 288 -104 288 -87 13 309
# /generate hill 372 -65 396 -55 16 900
# /generate hill 385 -221 394 -212 32 736
# /generate hill 330 -21 446 -16 26 100
# /generate river 378 -150 456 -97 29 358
# /generate river 492 -168 408 -118 17 193
# /generate river 321 -212 311 -158 10 927
# /generate river 444 -79 442 -164 22 388
# /generate river 401 -237 506 -254 17 84
# /generate river 290 -223 321 -16 19 677
# /generate river 277 -79 349 -189 17 470
# /generate river 418 -48 333 -81 6 920
# /generate river 333 -123 307 -89 19 20
# /generate river 321 -212 311 -158 10 927
# /generate river 444 -79 442 -164 22 388
# /generate river 401 -237 506 -254 17 84
# /generate river 290 -223 321 -16 19 677
# /generate river 277 -79 349 -189 17 470
# /generate river 418 -48 333 -81 6 920
# /generate river 333 -123 307 -89 19 20
# /generate river 321 -212 311 -158 10 927
# /generate river 444 -79 442 -164 22 388
# /generate river 401 -237 506 -254 17 84
# /generate river 290 -223 321 -16 19 677
# /generate river 277 -79 349 -189 17 470
# /generate river 418 -48 333 -81 6 920
# /generate river 333 -123 307 -89 19 20
# /generate lake 501 -115 square 26 10
# /generate lake 292 -97 square 32 58
# /generate lake 460 -4 square 84 31
# /generate lake 317 -48 circle 49
# /generate lake 463 -101 square 96 45
# /generate village 300 -15
# /generate forest 404 -173 22 low birch 578
# /generate forest 400 -180 10 low birch 365
# /generate forest 281 -113 21 low any 396
# /generate forest 305 -211 13 low oak 353
# /generate grass 323 -152 46 low
# /generate grass 341 -158 29 high
# /generate grass 437 -85 47 low
# /generate grass 295 -153 1 low
# /generate grass 386 -73 45 low
# /generate grass 458 -162 30 med
# /generate grass 404 -74 37 low
# /generate grass 369 -246 27 low
# /generate grass 318 -146 28 low
# /generate grass 421 -252 17 med
# /generate grass 455 -147 37 high
# /generate grass 409 -161 7 high
# /generate grass 374 -63 5 low
# /generate grass 313 -17 42 low
# /generate grass 425 -145 24 low
# /generate grass 502 -183 32 low
# /generate grass 294 -59 48 low
# /generate grass 359 -151 28 med
# /generate grass 356 -151 48 low
# /generate grass 449 -209 50 low
# /generate grass 459 -159 22 med
# /generate grass 265 -23 12 med
# /generate grass 277 -77 9 low
# /generate grass 425 -177 46 low
# /generate grass 257 -229 43 low
# /generate flowers 367 -142 50 high 856
# /generate flowers 331 -77 3 low 824
# /generate flowers 417 -189 36 low 48
# /generate flowers 288 -104 1 low 309
#
# Tile: SouthWest
# /generate hill -59 -16 -33 -10 13 202
# /generate hill -244 -190 -103 -74 33 692
# /generate hill -9 -116 -7 -43 36 189
# /generate hill -163 -97 -138 -8 24 118
# /generate river -67 -232 -116 -146 6 786
# /generate river -192 -16 -158 -105 2 594
# /generate river -76 -224 -36 -24 19 47
# /generate river -79 -92 -117 -93 24 351
# /generate river -48 -13 -160 -237 13 302
# /generate river -203 -110 -49 -69 20 407
# /generate river -239 -11 -131 -41 9 765
# /generate river -203 -227 -85 -83 27 181
# /generate river -242 -149 -40 -95 26 196
# /generate lake -57 -147 circle 68
# /generate lake -17 -161 circle 14
# /generate village -194 -81
# /generate forest -209 -50 19 low any 359
# /generate forest -48 -13 7 low any 302
# /generate forest -203 -110 18 med birch 407
# /generate forest -239 -11 8 low any 765
# /generate forest -73 -53 24 low oak 941
# /generate forest -104 -196 25 med any 747
# /generate grass -66 -75 17 low
# /generate grass -178 -147 12 low
# /generate grass -65 -95 11 low
# /generate grass -58 -168 3 med
# /generate grass -100 -12 2 low
# /generate grass -59 -16 27 low
# /generate grass -233 -152 48 med
# /generate grass -188 -185 40 low
# /generate grass -128 -12 23 low
# /generate grass -20 -168 20 med
# /generate grass -118 -105 4 low
# /generate grass -61 -86 15 low
# /generate grass -12 -177 39 high
# /generate grass -202 -202 41 low
# /generate flowers -235 -79 12 low 470
# /generate flowers -94 -48 42 low 920
# /generate flowers -182 -50 49 low 191
# /generate flowers -14 -14 36 low 490
# /generate flowers -127 -90 13 low 77
# /generate flowers -222 -7 12 low 842
# /generate flowers -79 -92 47 low 351
#
# Tile: NorthWest
# /generate hill -203 498 -124 498 30 326
# /generate hill -83 382 -48 431 14 415
# /generate hill -167 264 -148 419 13 933
# /generate hill -241 499 -196 508 30 141
# /generate hill -188 288 -123 318 32 1
# /generate hill -167 462 -39 474 15 779
# /generate hill -12 496 -11 503 33 293
# /generate hill -40 357 -11 489 10 534
# /generate river -255 303 -2 260 29 364
# /generate river -11 397 -110 356 3 27
# /generate river -220 415 -34 382 26 66
# /generate river -26 494 -34 455 26 456
# /generate river -25 300 -117 415 4 910
# /generate river -202 466 -178 316 30 932
# /generate river -71 496 -10 401 14 16
# /generate river -113 319 -137 297 3 232
# /generate lake -150 465 square 71 59
# /generate lake -222 408 square 42 46
# /generate lake -58 461 circle 72
# /generate lake -49 326 square 81 2
# /generate lake -46 397 square 6 53
# /generate lake -79 275 circle 10
# /generate lake -3 436 circle 12
# /generate lake -169 274 circle 39
# /generate forest -126 508 22 low any 421
# /generate grass -66 270 30 low
# /generate grass -117 340 36 low
# /generate grass -47 452 38 med
# /generate grass -70 380 33 low
# /generate grass -236 391 19 low
# /generate grass -124 483 8 low
# /generate grass -236 302 28 med
# /generate grass -180 387 20 low
# /generate grass -123 371 31 low
# /generate grass -216 507 31 low
# /generate grass -191 419 23 low
# /generate grass -6 414 28 med
# /generate grass -128 500 23 low
# /generate grass -20 344 20 med
# /generate grass -118 407 4 low
# /generate flowers -236 302 28 low 259
# /generate flowers -180 387 20 low 505
# /generate flowers -123 371 31 low 718
# /generate flowers -216 507 31 low 999
# /generate flowers -191 419 23 low 817
# /generate flowers -6 414 28 med 256

# %%
third_limits = {
    "hillCount": 20, "hillHeight": 40,
    "riverCount": 60, "riverWidth": 50,
    "lakeCount": 30, "lakeRadius": 150,
    "villageCount": 1,
    "forestCount": 10, "forestRadius": 50, "treeCount": 30,
    "grassCount": 30, "grassRadius": 50,
    "flowersCount": 10, "flowersRadius": 50,
    "densityLowProbability": 0.8, "densityMedProbability": 0.15, "densityHighProbability": 0.05
}

genWorld(third_limits)
# Out:
# Global Seed: 758
#
# Tile: Central
# /generate hill 243 63 253 219 26 64
# /generate hill 103 240 144 255 12 549
# /generate hill 144 240 184 255 5 295
# /generate hill 68 41 224 147 37 937
# /generate hill 189 253 234 253 25 236
# /generate hill 43 254 55 254 36 725
# /generate hill 197 135 231 140 34 558
# /generate hill 149 255 211 255 28 712
# /generate hill 46 21 171 174 14 203
# /generate hill 38 177 191 254 19 29
# /generate river 39 119 197 10 9 522
# /generate river 36 92 165 156 25 748
# /generate river 39 204 20 117 41 46
# /generate river 29 156 48 240 32 528
# /generate river 20 225 55 1 23 728
# /generate lake 3 99 circle 139
# /generate lake 169 79 circle 37
# /generate lake 141 107 square 119 22
# /generate lake 17 201 circle 12
# /generate lake 91 20 square 17 56
# /generate lake 217 55 square 131 34
# /generate lake 165 4 square 40 52
# /generate lake 20 13 circle 80
# /generate lake 65 194 square 14 132
# /generate lake 15 243 circle 147
# /generate lake 59 35 square 32 78
# /generate lake 139 70 circle 40
# /generate lake 79 25 square 68 71
# /generate lake 166 21 square 113 62
# /generate lake 150 150 circle 98
# /generate lake 158 147 circle 80
# /generate lake 231 193 circle 82
# /generate lake 22 66 circle 29
# /generate lake 63 178 square 34 91
# /generate lake 189 24 square 56 41
# /generate lake 64 240 circle 76
# /generate lake 137 27 square 95 105
# /generate lake 182 14 circle 8
# /generate lake 21 42 square 115 48
# /generate lake 159 51 square 60 110
# /generate lake 218 159 circle 55
# /generate lake 144 198 square 24 65
# /generate lake 81 56 square 87 14
# /generate lake 209 104 square 73 95
# /generate forest 104 194 2 low oak 468
# /generate forest 149 255 16 low oak 712
# /generate forest 46 21 27 low birch 203
# /generate forest 38 177 20 low oak 29
# /generate forest 203 97 11 med birch 88
# /generate forest 54 126 9 med any 14
# /generate forest 57 165 14 low birch 751
# /generate grass 163 93 14 low
# /generate grass 68 235 23 low
# /generate grass 141 64 8 low
# /generate grass 104 194 4 low
# /generate grass 74 206 49 low
# /generate grass 242 242 36 low
# /generate grass 129 166 13 low
# /generate grass 34 249 12 low
# /generate grass 177 164 47 low
# /generate grass 145 20 2 low
# /generate grass 216 80 26 low
# /generate grass 148 83 43 low
# /generate grass 157 83 34 low
# /generate grass 172 234 5 low
# /generate grass 180 98 27 low
# /generate grass 245 76 36 low
# /generate grass 183 115 23 med
# /generate flowers 112 28 9 low 981
# /generate flowers 16 170 43 low 966
# /generate flowers 36 25 26 low 330
# /generate flowers 152 76 4 low 341
# /generate flowers 159 51 20 low 574
# /generate flowers 218 159 12 low 980
# /generate flowers 144 198 37 med 285
#
# Tile: North
# /generate hill 135 408 220 440 27 469
# /generate hill 89 468 168 473 35 661
# /generate hill 115 369 180 450 8 761
# /generate hill 182 433 247 486 1 595
# /generate hill 71 371 207 481 17 229
# /generate hill 28 410 193 418 35 845
# /generate hill 116 447 140 457 16 900
# /generate hill 129 291 138 300 32 736
# /generate hill 74 491 190 496 26 100
# /generate hill 233 484 253 489 28 749
# /generate hill 57 325 216 403 4 323
# /generate hill 242 352 252 498 30 556
# /generate hill 172 372 221 468 8 832
# /generate hill 146 469 215 503 27 155
# /generate hill 105 409 225 433 38 829
# /generate hill 200 332 227 502 30 956
# /generate hill 220 406 227 480 10 901
# /generate hill 189 428 191 444 39 395
# /generate river 44 367 203 346 40 121
# /generate river 240 419 248 294 35 818
# /generate river 44 497 141 393 37 930
# /generate river 133 371 33 456 36 573
# /generate river 112 284 70 436 24 981
# /generate river 167 407 49 380 23 729
# /generate river 234 344 252 401 14 163
# /generate river 118 412 124 299 14 360
# /generate river 240 398 51 486 28 694
# /generate river 37 385 190 279 41 296
# /generate river 86 437 187 267 6 874
# /generate river 48 271 136 265 35 140
# /generate river 233 484 87 476 21 749
# /generate river 25 418 79 500 42 703
# /generate river 28 422 23 446 40 255
# /generate river 5 340 52 435 1 769
# /generate river 106 465 233 491 30 840
# /generate river 122 362 200 415 13 358
# /generate river 185 496 246 401 27 16
# /generate river 143 319 119 297 5 232
# /generate river 133 424 211 368 39 875
# /generate river 190 417 20 351 18 487
# /generate river 5 340 52 435 1 769
# /generate river 106 465 233 491 30 840
# /generate river 122 362 200 415 13 358
# /generate river 185 496 246 401 27 16
# /generate river 143 319 119 297 5 232
# /generate river 133 424 211 368 39 875
# /generate river 190 417 20 351 18 487
# /generate river 5 340 52 435 1 769
# /generate river 106 465 233 491 30 840
# /generate river 122 362 200 415 13 358
# /generate river 185 496 246 401 27 16
# /generate river 143 319 119 297 5 232
# /generate river 133 424 211 368 39 875
# /generate river 190 417 20 351 18 487
# /generate river 5 340 52 435 1 769
# /generate river 106 465 233 491 30 840
# /generate river 122 362 200 415 13 358
# /generate forest 110 489 17 low any 53
# /generate grass 217 322 2 low
# /generate grass 243 319 41 low
# /generate grass 103 496 11 low
# /generate grass 10 294 43 high
# /generate grass 5 340 40 low
# /generate grass 116 447 49 low
# /generate grass 102 310 21 low
# /generate grass 14 363 50 med
# /generate grass 63 482 7 low
# /generate grass 72 470 26 low
# /generate grass 135 432 41 low
# /generate grass 218 415 12 low
# /generate grass 144 454 37 med
# /generate grass 65 508 2 low
# /generate grass 132 404 44 low
# /generate grass 251 411 49 med
# /generate grass 189 509 47 low
# /generate grass 45 488 1 low
# /generate grass 141 456 9 low
# /generate grass 79 303 26 low
# /generate grass 7 397 26 med
# /generate grass 39 460 3 low
# /generate flowers 17 457 12 low 908
# /generate flowers 91 276 45 low 319
# /generate flowers 187 318 15 low 626
# /generate flowers 37 348 27 low 137
# /generate flowers 7 323 11 low 197
# /generate flowers 191 409 6 low 192
# /generate flowers 16 426 43 low 966
# /generate flowers 36 281 26 low 330
# /generate flowers 152 332 4 low 341
#
# Tile: East
# /generate hill 461 75 482 217 33 868
# /generate lake 311 120 square 79 9
# /generate lake 294 177 square 23 131
# /generate village 506 49
# /generate forest 445 61 2 low birch 562
# /generate forest 301 232 1 low any 390
# /generate forest 347 162 18 low birch 648
# /generate forest 401 100 25 high oak 115
# /generate forest 317 107 19 low oak 342
# /generate forest 332 9 1 low oak 494
# /generate forest 509 202 16 high any 491
# /generate forest 319 226 4 med any 663
# /generate forest 311 95 16 low any 803
# /generate forest 483 195 24 low oak 251
# /generate grass 264 149 35 low
# /generate grass 283 246 7 low
# /generate grass 347 221 33 low
# /generate grass 502 223 43 med
# /generate grass 391 152 43 low
# /generate grass 345 212 20 low
# /generate grass 321 163 23 med
# /generate grass 506 158 28 med
# /generate grass 384 244 23 low
# /generate grass 492 88 20 med
# /generate grass 394 151 4 low
# /generate grass 451 170 15 low
# /generate grass 500 79 39 high
# /generate grass 310 54 41 low
# /generate grass 393 27 16 low
# /generate grass 278 50 2 low
# /generate grass 385 224 22 low
# /generate grass 369 81 2 low
# /generate flowers 402 213 35 high 155
# /generate flowers 361 153 31 low 829
# /generate flowers 344 222 35 med 605
# /generate flowers 509 93 36 low 61
# /generate flowers 412 208 35 low 928
# /generate flowers 293 92 27 low 137
# /generate flowers 263 67 11 low 197
# /generate flowers 447 153 6 low 192
# /generate flowers 272 170 43 low 966
# /generate flowers 292 25 26 low 330
#
# Tile: South
# /generate hill 185 -16 246 -7 27 16
# /generate hill 143 -193 172 -173 5 232
# /generate hill 133 -88 185 -10 15 875
# /generate hill 242 -24 255 -16 21 617
# /generate hill 132 -29 146 -4 37 837
# /generate hill 20 -210 131 -58 32 259
# /generate hill 180 -158 232 -124 25 670
# /generate hill 245 -180 253 -73 7 409
# /generate hill 64 -246 227 -81 18 443
# /generate hill 96 -1 136 -1 37 343
# /generate hill 93 -193 164 -116 28 94
# /generate hill 211 -53 226 -14 15 869
# /generate hill 129 -11 180 -10 2 467
# /generate hill 249 -224 255 -18 25 432
# /generate hill 71 -181 111 -58 22 485
# /generate hill 87 -238 224 -198 20 363
# /generate hill 19 -207 224 -165 5 69
# /generate river 145 -183 32 -118 9 352
# /generate river 32 -153 197 -69 44 604
# /generate river 119 -212 91 -164 16 889
# /generate river 88 -34 253 -205 4 605
# /generate river 63 -109 143 -213 19 370
# /generate river 128 -202 64 -141 2 627
# /generate river 191 -128 209 -82 14 254
# /generate river 121 -190 189 -14 41 3
# /generate river 64 -16 98 -105 4 594
# /generate river 180 -224 220 -24 37 47
# /generate river 177 -92 139 -93 47 351
# /generate river 208 -13 96 -237 25 302
# /generate river 53 -110 207 -69 40 407
# /generate river 17 -11 125 -41 18 765
# /generate river 53 -227 171 -83 13 181
# /generate river 195 -166 231 -192 48 770
# /generate river 171 -189 174 -178 19 35
# /generate river 187 -29 230 -40 27 442
# /generate river 88 -167 250 -128 12 486
# /generate river 247 -240 25 -168 24 226
# /generate river 177 -92 139 -93 47 351
# /generate river 208 -13 96 -237 25 302
# /generate river 53 -110 207 -69 40 407
# /generate river 17 -11 125 -41 18 765
# /generate river 53 -227 171 -83 13 181
# /generate river 195 -166 231 -192 48 770
# /generate river 171 -189 174 -178 19 35
# /generate river 187 -29 230 -40 27 442
# /generate river 88 -167 250 -128 12 486
# /generate river 247 -240 25 -168 24 226
# /generate river 177 -92 139 -93 47 351
# /generate river 208 -13 96 -237 25 302
# /generate river 53 -110 207 -69 40 407
# /generate river 17 -11 125 -41 18 765
# /generate river 53 -227 171 -83 13 181
# /generate river 195 -166 231 -192 48 770
# /generate river 171 -189 174 -178 19 35
# /generate river 187 -29 230 -40 27 442
# /generate lake 232 -21 circle 126
# /generate lake 106 -162 square 122 5
# /generate lake 152 -50 square 107 13
# /generate lake 138 -105 circle 103
# /generate lake 195 -86 circle 43
# /generate lake 244 -177 square 144 7
# /generate lake 133 -141 square 112 34
# /generate lake 40 -5 square 34 82
# /generate lake 149 -11 circle 4
# /generate lake 117 -28 square 95 148
# /generate lake 190 -221 circle 82
# /generate lake 150 -2 square 11 124
# /generate lake 183 -141 square 116 23
# /generate lake 76 -190 circle 114
# /generate lake 79 -231 square 68 71
# /generate forest 67 -88 26 low oak 380
# /generate forest 1 -229 28 low any 849
# /generate forest 111 -142 25 low birch 856
# /generate forest 200 -182 13 low any 152
# /generate forest 200 -181 12 high oak 639
# /generate forest 81 -200 20 high any 355
# /generate forest 209 -152 12 low oak 151
# /generate grass 166 -235 42 med
# /generate grass 21 -15 17 low
# /generate grass 145 -83 14 low
# /generate grass 219 -225 28 low
# /generate grass 4 -216 20 low
# /generate grass 71 -141 35 high
# /generate grass 247 -74 22 low
# /generate grass 245 -15 37 low
# /generate grass 159 -160 36 low
# /generate flowers 143 -202 20 low 544
# /generate flowers 144 -58 37 low 285
# /generate flowers 65 -4 2 low 95
# /generate flowers 132 -108 44 low 13
# /generate flowers 251 -101 49 med 821
# /generate flowers 189 -3 47 low 236
#
# Tile: West
# /generate hill -24 173 -7 241 25 81
# /generate hill -14 242 -6 253 5 490
# /generate hill -51 170 -32 178 20 755
# /generate hill -141 109 -85 134 23 612
# /generate hill -74 143 -12 221 3 827
# /generate hill -118 151 -112 252 26 538
# /generate hill -61 170 -47 191 25 41
# /generate hill -63 57 -35 89 6 591
# /generate hill -203 29 -118 115 13 181
# /generate hill -61 90 -3 205 9 770
# /generate hill -21 138 -2 248 39 756
# /generate river -143 10 -41 235 23 741
# /generate river -194 110 -38 35 34 967
# /generate river -217 109 -182 155 45 32
# /generate river -79 179 -49 41 39 921
# /generate river -203 29 -85 173 13 181
# /generate river -61 90 -25 64 48 770
# /generate river -85 67 -82 78 19 35
# /generate river -69 227 -26 216 27 442
# /generate river -168 89 -6 128 12 486
# /generate river -9 16 -231 88 24 226
# /generate river -79 164 -117 163 47 351
# /generate river -48 243 -160 19 25 302
# /generate river -203 146 -49 187 40 407
# /generate river -239 245 -131 215 18 765
# /generate river -203 29 -85 173 13 181
# /generate river -61 90 -25 64 48 770
# /generate river -85 67 -82 78 19 35
# /generate river -69 227 -26 216 27 442
# /generate river -168 89 -6 128 12 486
# /generate river -9 16 -231 88 24 226
# /generate river -79 164 -117 163 47 351
# /generate river -48 243 -160 19 25 302
# /generate river -203 146 -49 187 40 407
# /generate lake -121 152 square 107 98
# /generate lake -20 61 circle 110
# /generate lake -126 89 circle 136
# /generate lake -231 194 circle 79
# /generate lake -20 61 circle 110
# /generate lake -126 89 circle 136
# /generate lake -231 194 circle 79
# /generate lake -20 61 circle 110
# /generate lake -126 89 circle 136
# /generate lake -231 194 circle 79
# /generate lake -20 61 circle 110
# /generate lake -126 89 circle 136
# /generate lake -231 194 circle 79
# /generate lake -20 61 circle 110
# /generate lake -126 89 circle 136
# /generate lake -231 194 circle 79
# /generate lake -20 61 circle 110
# /generate lake -126 89 circle 136
# /generate lake -231 194 circle 79
# /generate lake -20 61 circle 110
# /generate lake -126 89 circle 136
# /generate lake -231 194 circle 79
# /generate lake -20 61 circle 110
# /generate grass -154 2 12 low
# /generate grass -29 127 15 low
# /generate grass -88 54 48 low
# /generate grass -75 171 47 med
# /generate grass -217 103 1 low
# /generate flowers -151 153 31 low 829
# /generate flowers -168 222 35 med 605
# /generate flowers -3 93 36 low 61
# /generate flowers -100 208 35 low 928
# /generate flowers -219 92 27 low 137
#
# Tile: NorthEast
# /generate hill 263 323 304 328 13 197
# /generate hill 307 335 372 444 7 597
# /generate hill 359 496 400 511 12 549
# /generate hill 400 496 440 511 5 295
# /generate hill 324 297 480 403 37 937
# /generate hill 445 509 490 509 25 236
# /generate hill 299 510 311 510 36 725
# /generate hill 453 391 487 396 34 558
# /generate hill 405 511 467 511 28 712
# /generate hill 302 277 427 430 14 203
# /generate river 466 397 475 277 27 798
# /generate lake 458 366 circle 68
# /generate lake 303 277 square 98 16
# /generate lake 301 433 circle 111
# /generate lake 375 300 circle 140
# /generate lake 397 259 circle 84
# /generate lake 408 332 circle 10
# /generate lake 461 331 square 143 131
# /generate forest 452 349 7 low oak 24
# /generate grass 406 406 44 low
# /generate grass 508 342 46 med
# /generate grass 375 358 38 low
# /generate grass 290 289 44 low
# /generate grass 293 495 33 low
# /generate flowers 303 277 46 low 925
# /generate flowers 491 394 40 low 756
#
# Tile: SouthEast
# /generate hill 462 -182 476 -60 7 383
# /generate hill 309 -151 399 -122 32 801
# /generate hill 445 -95 495 -69 7 96
# /generate hill 388 -29 402 -4 37 837
# /generate hill 276 -210 387 -58 32 259
# /generate hill 436 -158 488 -124 25 670
# /generate hill 501 -180 509 -73 7 409
# /generate hill 320 -246 483 -81 18 443
# /generate hill 352 -1 392 -1 37 343
# /generate hill 349 -193 420 -116 28 94
# /generate hill 467 -53 482 -14 15 869
# /generate hill 385 -11 436 -10 2 467
# /generate hill 505 -224 511 -18 25 432
# /generate hill 327 -181 367 -58 22 485
# /generate hill 343 -238 480 -198 20 363
# /generate hill 275 -207 480 -165 5 69
# /generate hill 259 -180 380 -15 12 619
# /generate hill 314 -231 430 -183 3 952
# /generate hill 386 -167 457 -37 8 169
# /generate river 281 -62 351 -100 42 809
# /generate river 331 -21 350 -108 17 991
# /generate river 508 -144 293 -113 4 805
# /generate river 500 -177 445 -243 45 923
# /generate river 269 -70 395 -50 7 420
# /generate river 312 -127 419 -74 30 782
# /generate river 383 -42 457 -166 1 332
# /generate river 327 -141 476 -121 41 229
# /generate river 301 -79 337 -35 44 858
# /generate river 360 -170 373 -11 3 161
# /generate river 309 -88 280 -158 10 772
# /generate river 292 -231 461 -248 22 330
# /generate river 401 -83 363 -168 39 631
# /generate river 475 -225 477 -3 49 136
# /generate river 260 -216 412 -142 9 206
# /generate river 290 -230 301 -33 25 917
# /generate river 412 -48 328 -188 50 928
# /generate river 495 -161 366 -204 24 979
# /generate river 318 -81 460 -167 38 160
# /generate river 303 -50 506 -105 49 359
# /generate river 339 -7 440 -233 11 427
# /generate river 438 -80 256 -5 23 300
# /generate river 439 -254 495 -64 10 541
# /generate river 433 -79 502 -245 9 905
# /generate river 317 -210 458 -21 50 397
# /generate river 275 -84 457 -211 42 752
# /generate river 355 -76 501 -161 43 739
# /generate river 304 -241 392 -247 35 140
# /generate river 489 -28 343 -36 21 749
# /generate river 281 -94 335 -12 42 703
# /generate river 284 -90 279 -66 40 255
# /generate river 261 -172 308 -77 1 769
# /generate river 362 -47 489 -21 30 840
# /generate lake 368 -141 circle 120
# /generate lake 406 -215 square 38 112
# /generate lake 428 -69 square 69 69
# /generate lake 385 -42 square 23 86
# /generate lake 405 -244 circle 1
# /generate lake 337 -86 circle 123
# /generate lake 373 -3 square 115 66
# /generate lake 368 -69 circle 8
# /generate lake 453 -107 circle 82
# /generate lake 349 -109 circle 112
# /generate lake 269 -250 square 3 58
# /generate forest 502 -199 6 low birch 542
# /generate forest 408 -10 24 low oak 460
# /generate forest 261 -172 20 low any 769
# /generate forest 378 -150 13 low any 358
# /generate forest 441 -16 16 low oak 16
# /generate forest 349 -81 18 low oak 457
# /generate forest 496 -187 14 low any 664
# /generate grass 403 -227 7 low
# /generate grass 378 -164 11 high
# /generate grass 397 -36 42 low
# /generate grass 345 -44 20 low
# /generate grass 321 -93 23 med
# /generate grass 506 -98 28 med
# /generate grass 384 -12 23 low
# /generate grass 492 -168 20 med
# /generate grass 394 -105 4 low
# /generate grass 451 -86 15 low
# /generate grass 500 -177 39 high
# /generate grass 310 -202 41 low
# /generate grass 393 -229 16 low
# /generate flowers 470 -3 5 low 508
#
# Tile: SouthWest
# /generate hill -155 -245 -42 -158 7 267
# /generate hill -240 -37 -117 -1 1 10
# /generate hill -74 -133 -72 -53 36 211
# /generate river -54 -146 -146 -121 32 942
# /generate river -253 -180 -14 -164 35 619
# /generate river -51 -115 -136 -132 4 891
# /generate river -101 -90 -122 -39 35 454
# /generate river -54 -235 -226 -103 36 212
# /generate river -4 -75 -10 -91 50 133
# /generate river -23 -177 -216 -69 14 630
# /generate river -96 -47 -17 -81 24 262
# /generate river -51 -181 -88 -249 5 868
# /generate river -201 -136 -111 -100 3 222
# /generate river -218 -79 -109 -212 33 29
# /generate river -84 -69 -96 -120 40 949
# /generate river -193 -66 -105 -93 12 275
# /generate river -51 -115 -136 -132 4 891
# /generate river -101 -90 -122 -39 35 454
# /generate river -54 -235 -226 -103 36 212
# /generate river -4 -75 -10 -91 50 133
# /generate river -23 -177 -216 -69 14 630
# /generate river -96 -47 -17 -81 24 262
# /generate river -51 -181 -88 -249 5 868
# /generate river -201 -136 -111 -100 3 222
# /generate river -218 -79 -109 -212 33 29
# /generate river -84 -69 -96 -120 40 949
# /generate river -193 -66 -105 -93 12 275
# /generate river -51 -115 -136 -132 4 891
# /generate river -101 -90 -122 -39 35 454
# /generate river -54 -235 -226 -103 36 212
# /generate river -4 -75 -10 -91 50 133
# /generate river -23 -177 -216 -69 14 630
# /generate river -96 -47 -17 -81 24 262
# /generate river -51 -181 -88 -249 5 868
# /generate river -201 -136 -111 -100 3 222
# /generate river -218 -79 -109 -212 33 29
# /generate river -84 -69 -96 -120 40 949
# /generate river -193 -66 -105 -93 12 275
# /generate river -51 -115 -136 -132 4 891
# /generate river -101 -90 -122 -39 35 454
# /generate river -54 -235 -226 -103 36 212
# /generate river -4 -75 -10 -91 50 133
# /generate river -23 -177 -216 -69 14 630
# /generate river -96 -47 -17 -81 24 262
# /generate lake -104 -180 circle 10
# /generate lake -51 -181 square 143 131
# /generate lake -202 -130 square 66 75
# /generate lake -199 -91 square 141 88
# /generate lake -158 -116 circle 33
# /generate lake -97 -205 square 60 110
# /generate lake -38 -97 circle 55
# /generate lake -112 -58 square 24 65
# /generate lake -175 -200 square 87 14
# /generate lake -47 -152 square 73 95
# /generate lake -90 -235 square 113 62
# /generate lake -106 -106 circle 98
# /generate lake -98 -109 circle 80
# /generate lake -25 -63 circle 82
# /generate lake -234 -190 circle 29
# /generate lake -193 -78 square 34 91
# /generate lake -67 -232 square 56 41
# /generate lake -192 -16 circle 76
# /generate lake -119 -229 square 95 105
# /generate lake -74 -242 circle 8
# /generate lake -235 -214 square 115 48
# /generate lake -97 -205 square 60 110
# /generate lake -38 -97 circle 55
# /generate lake -112 -58 square 24 65
# /generate lake -175 -200 square 87 14
# /generate lake -47 -152 square 73 95
# /generate lake -90 -235 square 113 62
# /generate village -42 -192
# /generate forest -89 -105 19 low oak 729
# /generate grass -51 -24 32 low
# /generate grass -182 -61 3 low
# /generate grass -130 -61 27 low
# /generate grass -147 -129 26 low
# /generate grass -28 -211 29 low
# /generate grass -246 -155 47 low
# /generate grass -99 -127 6 low
# /generate grass -46 -115 28 low
# /generate grass -79 -237 16 low
# /generate grass -185 -132 2 low
# /generate grass -163 -81 36 low
# /generate grass -165 -2 9 low
# /generate grass -203 -227 22 low
# /generate grass -129 -122 11 med
# /generate grass -97 -205 20 low
# /generate grass -38 -97 12 low
# /generate grass -112 -58 37 med
# /generate grass -191 -4 2 low
# /generate grass -124 -108 44 low
# /generate grass -5 -101 49 med
# /generate grass -67 -3 47 low
# /generate flowers -213 -2 4 low 725
# /generate flowers -59 -121 35 low 558
# /generate flowers -107 -1 32 low 712
# /generate flowers -61 -10 50 low 436
# /generate flowers -201 -210 48 low 183
#
# Tile: NorthWest
# /generate river -224 408 -256 324 13 309
# /generate river -140 447 -208 298 45 900
# /generate river -118 398 -3 336 1 249
# /generate river -55 320 -215 501 38 797
# /generate river -165 477 -224 473 1 489
# /generate river -146 489 -9 440 47 53
# /generate river -158 369 -225 269 12 465
# /generate river -113 319 -137 297 5 232
# /generate river -123 424 -45 368 39 875
# /generate river -66 417 -236 351 18 487
# /generate river -251 340 -204 435 1 769
# /generate river -150 465 -23 491 30 840
# /generate river -134 362 -56 415 13 358
# /generate river -71 496 -10 401 27 16
# /generate river -113 319 -137 297 5 232
# /generate river -123 424 -45 368 39 875
# /generate river -66 417 -236 351 18 487
# /generate river -251 340 -204 435 1 769
# /generate river -150 465 -23 491 30 840
# /generate river -134 362 -56 415 13 358
# /generate river -71 496 -10 401 27 16
# /generate river -113 319 -137 297 5 232
# /generate lake -3 286 circle 77
# /generate lake -100 500 square 39 95
# /generate lake -69 318 circle 6
# /generate lake -49 326 square 4 28
# /generate lake -178 365 circle 15
# /generate lake -48 499 circle 10
# /generate lake -31 360 circle 48
# /generate lake -192 266 square 100 68
# /generate lake -198 445 square 48 57
# /generate lake -146 284 circle 128
# /generate lake -182 480 square 42 62
# /generate lake -29 451 square 64 106
# /generate lake -169 285 square 41 135
# /generate lake -13 319 square 138 5
# /generate lake -114 356 circle 147
# /generate lake -174 310 square 123 24
# /generate lake -95 323 square 130 50
# /generate lake -221 309 circle 100
# /generate lake -135 460 square 99 135
# /generate lake -223 510 square 134 79
# /generate lake -71 496 square 73 107
# /generate lake -113 319 circle 21
# /generate lake -26 479 square 11 132
# /generate lake -175 426 circle 123
# /generate lake -139 509 square 115 66
# /generate lake -144 443 circle 8
# /generate lake -59 405 circle 82
# /generate forest -221 281 14 low oak 474
# /generate forest -163 456 21 high oak 305
# /generate forest -146 511 14 low any 177
# /generate forest -29 503 8 low any 996
# /generate forest -192 482 19 low birch 531
# /generate forest -68 478 30 low any 885
# /generate forest -150 298 24 med birch 438
# /generate forest -228 441 22 med any 606
# /generate forest -37 287 14 low birch 136
# /generate grass -7 288 50 low
# /generate grass -67 428 2 med
# /generate grass -240 426 43 med
# /generate grass -220 281 26 low
# /generate grass -104 332 4 low
# /generate grass -97 307 20 low
# /generate grass -38 415 12 low
# /generate grass -112 454 37 med
# /generate grass -191 508 2 low
# /generate grass -124 404 44 low
# /generate grass -5 411 49 med
# /generate grass -67 509 47 low
# /generate grass -211 488 1 low
# /generate grass -115 456 9 low
# /generate grass -177 303 26 low
# /generate flowers -12 366 12 low 446
# /generate flowers -40 383 6 low 445
# /generate flowers -155 443 1 low 992
